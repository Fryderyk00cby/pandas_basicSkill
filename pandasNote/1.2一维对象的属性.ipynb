# %%
import pandas as pd

# %% [markdown]
# 1.2一维对象的属性

# %%
arr_v = [0,1,2,3,4]
arr_k = ['a','b','c','d','e']
s = pd.Series(arr_v,index=arr_k)
print(s)
# Out:
# a    0
# b    1
# c    2
# d    3
# e    4
# dtype: int64

# %%
#查看values和index属性
print(s.values) #返回一个numpy数组（无论创建时是列表、数组还是张量）
print(s.index) #返回一个Index对象，Index对象是不可变的，可以看成是一个特殊的数组
# Out:
# [0 1 2 3 4]
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')
