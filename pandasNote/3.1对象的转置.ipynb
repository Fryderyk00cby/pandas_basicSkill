# %%
import pandas as pd

# %% [markdown]
# 3.1 对象的转置

# %%
#创建畸形df
v = [[53,64,73,85],['女','男','女','男']]
i = ['年龄', '性别']
c = ['1号','2号','3号','4号']
df = pd.DataFrame(v, index=i, columns=c)
print(df)
# Out:
#     1号  2号  3号  4号
# 年龄  53  64  73  85
# 性别   女   男   女   男

# %%
df = df.T #转置
print(df)
# Out:
#     年龄 性别
# 1号  53  女
# 2号  64  男
# 3号  73  女
# 4号  85  男
