# %%
import pandas as pd

# %% [markdown]
# 6.1 Excel文件相关操作

# %%
#创建的excel第一列为index 第一行为colunms（必须）
#必须转成csv文件类型
df = pd.read_csv('test_table.csv', index_col=0)
print(df)
# Out:
#     年龄  牌照
# 1号  64   2
# 2号  74   1
# 3号  25   3
# 4号  28   5
# 5号  46   6
# 6号  33   4

# %%
arr = df.values
print(arr)
# Out:
# [[64  2]
#  [74  1]
#  [25  3]
#  [28  5]
#  [46  6]
#  [33  4]]
